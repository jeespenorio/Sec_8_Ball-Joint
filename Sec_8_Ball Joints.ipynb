# %%
import pandas as pd

data1 = {
    'Make': ['Honda'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1015'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-04024'],
    
    'SKU': ['125411'],
    
}

list_models = [
    
'TRX350FE FourTrax Rancher 4x4 ES',
'TRX350FM FourTrax Rancher 4X4',
'TRX350TE FourTrax Rancher ES',
'TRX350TM FourTrax Rancher',
'TRX400FA FourTrax Rancher AT',
'TRX400FGA FourTrax Rancher AT GPScape',
    
'TRX420FA Rancher AT',
'TRX420FA2 FourTrax Rancher 4x4 Auto DCT with EPS',
'TRX420FA1 FourTrax Rancher 4x4 Auto DCT',
'TRX420FA5 FourTrax Rancher 4x4 Auto DCT IRS',
'TRX420FA6 FourTrax Rancher 4x4 Auto DCT IRS EPS',
'TRX420FE FourTrax Rancher 4X4 ES',
'TRX420FE1 FourTrax Rancher 4x4 ES',
'TRX420FM FourTrax Rancher 4X4',
'TRX420FM1 FourTrax Rancher 4x4',
'TRX420FM2 FourTrax Rancher 4x4 with EPS',
'TRX420FPA Rancher AT 4x4 w/ Power Steering',
'TRX420FPE Rancher ES 4x4 w/ Power Steering',
'TRX420FPM Rancher 4x4 w/ Power Steering',
'TRX420TE FourTrax Rancher ES',
'TRX420TM FourTrax Rancher',
'TRX420TM1 FourTrax Rancher',
'TRX420TE1 FourTrax Rancher ES',
    
'TRX450FE FourTrax Foreman ES',
'TRX450FM FourTrax Foreman S',
    
'TRX500FA FourTrax Foreman Rubicon',
'TRX500FGA FourTrax Foreman Rubicon GPScape',
'TRX500FE FourTrax Foreman 4x4 ES',
'TRX500FM FourTrax Foreman 4x4',
'TRX500FPE FourTrax Foreman 4x4 ES w/Power Steering',
'TRX500FPM FourTrax Foreman 4x4 w/ Power Steering',
'TRX500TM FourTrax Foreman',
'TRX500FPA FourTrax Foreman Rubicon with EPS',
'TRX500FM1 FourTrax Foreman 4x4',
'TRX500FE1 FourTrax Foreman 4x4 ES',
'TRX500FM2 FourTrax Foreman 4x4 with EPS',
'TRX500FE2 FourTrax Foreman 4x4 ES with EPS',
'TRX500FM5 FourTrax Foreman Rubicon',
'TRX500FM6 FourTrax Foreman Rubicon EPS',
'TRX500FM6D FourTrax Foreman Rubicon EPS DLX',
'TRX500FA5 FourTrax Foreman Rubicon Auto DCT',
'TRX500FA6 FourTrax Foreman Rubicon Auto DCT EPS',
'TRX500FA6D FourTrax Foreman Rubicon Auto DCT EPS D',
'TRX500FA7 FourTrax Foreman Rubicon Auto DCT EPS DL',
'TRX500FM7 FourTrax Foreman Rubicon EPS DLX',
'TRX520FM1 FourTrax Foreman 4x4',
'TRX520FM2 FourTrax Foreman 4x4 EPS',
'TRX520FE2 FourTrax Foreman 4x4 ES EPS',
'TRX520FM6 FourTrax Foreman Rubicon EPS',
'TRX520FA5 FourTrax Foreman Rubicon Auto DCT',
'TRX520FA6 FourTrax Foreman Rubicon Auto DCT EPS',
'TRX520FA7 FourTrax Foreman Rubicon Auto DCT EPS DL',
'TRX650FA FourTrax Rincon',
'TRX650FGA FourTrax Rincon GPScape',
'TRX680FA FourTrax Rincon',
'TRX680FGA FourTrax Rincon GPScape',
    
'TRX450ER Electric Start',
'SXS500M2 Pioneer 500',
'SXS700M4 Pioneer 700-4',
'SXS700M2 Pioneer 700',
'SXS700M2 Pioneer 700 Deluxe',
'SXS700M4 Pioneer 700-4 Deluxe',
'SXS1000M5 Pioneer 1000-5',
'SXS1000M5 Pioneer 1000-5 Deluxe',
'SXS1000M3 Pioneer 1000',
'SXS1000M3 Pioneer 1000 EPS',
'SXS1000M3 Pioneer 1000 Limited Edition',
'SXS1000M5 Pioneer 1000-5 Limited Edition',
'SXS1000M3 Pioneer 1000 Deluxe',
'SXS1000M5 Pioneer 1000-5 Special Edition',
'SXS1000M3 Pioneer 1000 Special Edition',
'SXS1000M5 Pioneer 1000-5 Trail',
'SXS1000M5 Pioneer 1000-5 Forest',
'SXS1000M3 Pioneer 1000 Forest',
'SXS1000M3 Pioneer 1000 Trail'


]

years = list(range(1998,2025))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                                   Model Vendor Code  \
# 0     Honda        TRX350FE FourTrax Rancher 4x4 ES        NACH
# 1     Honda           TRX350FM FourTrax Rancher 4X4        NACH
# 2     Honda            TRX350TE FourTrax Rancher ES        NACH
# 3     Honda               TRX350TM FourTrax Rancher        NACH
# 4     Honda            TRX400FA FourTrax Rancher AT        NACH
# ...     ...                                     ...         ...
# 2020  Honda  SXS1000M3 Pioneer 1000 Special Edition        NACH
# 2021  Honda          SXS1000M5 Pioneer 1000-5 Trail        NACH
# 2022  Honda         SXS1000M5 Pioneer 1000-5 Forest        NACH
# 2023  Honda           SXS1000M3 Pioneer 1000 Forest        NACH
# 2024  Honda            SXS1000M3 Pioneer 1000 Trail        NACH
#
#                         Vendor Name   Vendor Notes Classification  \
# 0     NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1015          Upper
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-04024.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Honda'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1015'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-04024'],
    
    'SKU': ['125411'],
    
}

list_models = [
    
'TRX420FA Rancher AT',
'TRX420FA2 FourTrax Rancher 4x4 Auto DCT with EPS',
'TRX420FA1 FourTrax Rancher 4x4 Auto DCT',
'TRX420FA5 FourTrax Rancher 4x4 Auto DCT IRS',
'TRX420FA6 FourTrax Rancher 4x4 Auto DCT IRS EPS',
'TRX420FE FourTrax Rancher 4X4 ES',
'TRX420FE1 FourTrax Rancher 4x4 ES',
'TRX420FM FourTrax Rancher 4X4',
'TRX420FM1 FourTrax Rancher 4x4',
'TRX420FM2 FourTrax Rancher 4x4 with EPS',
'TRX420FPA Rancher AT 4x4 w/ Power Steering',
'TRX420FPE Rancher ES 4x4 w/ Power Steering',
'TRX420FPM Rancher 4x4 w/ Power Steering',
'TRX420TE FourTrax Rancher ES',
'TRX420TM FourTrax Rancher',
'TRX420TM1 FourTrax Rancher',
'TRX420TE1 FourTrax Rancher ES',
'TRX450FE FourTrax Foreman ES',
'TRX450FM FourTrax Foreman S',
'TRX500FA FourTrax Foreman Rubicon',
'TRX500FGA FourTrax Foreman Rubicon GPScape',
'TRX500FE FourTrax Foreman 4x4 ES',
'TRX500FM FourTrax Foreman 4x4',
'TRX500FPE FourTrax Foreman 4x4 ES w/Power Steering',
'TRX500FPM FourTrax Foreman 4x4 w/ Power Steering',
'TRX500TM FourTrax Foreman',
'TRX500FPA FourTrax Foreman Rubicon with EPS',
'TRX500FM1 FourTrax Foreman 4x4',
'TRX500FE1 FourTrax Foreman 4x4 ES',
'TRX500FM2 FourTrax Foreman 4x4 with EPS',
'TRX500FE2 FourTrax Foreman 4x4 ES with EPS',
'TRX500FM5 FourTrax Foreman Rubicon',
'TRX500FM6 FourTrax Foreman Rubicon EPS',
'TRX500FM6D FourTrax Foreman Rubicon EPS DLX',
'TRX500FA5 FourTrax Foreman Rubicon Auto DCT',
'TRX500FA6 FourTrax Foreman Rubicon Auto DCT EPS',
'TRX500FA6D FourTrax Foreman Rubicon Auto DCT EPS D',
'TRX500FA7 FourTrax Foreman Rubicon Auto DCT EPS DL',
'TRX500FM7 FourTrax Foreman Rubicon EPS DLX',
'TRX520FM1 FourTrax Foreman 4x4',
'TRX520FM2 FourTrax Foreman 4x4 EPS',
'TRX520FE2 FourTrax Foreman 4x4 ES EPS',
'TRX520FM6 FourTrax Foreman Rubicon EPS',
'TRX520FA5 FourTrax Foreman Rubicon Auto DCT',
'TRX520FA6 FourTrax Foreman Rubicon Auto DCT EPS',
'TRX520FA7 FourTrax Foreman Rubicon Auto DCT EPS DL',
'TRX650FA FourTrax Rincon',
'TRX650FGA FourTrax Rincon GPScape',
'TRX680FA FourTrax Rincon',
'TRX680FGA FourTrax Rincon GPScape',
]

years = list(range(1998,2025))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                                              Model Vendor Code  \
# 0     Honda                                TRX420FA Rancher AT        NACH
# 1     Honda   TRX420FA2 FourTrax Rancher 4x4 Auto DCT with EPS        NACH
# 2     Honda            TRX420FA1 FourTrax Rancher 4x4 Auto DCT        NACH
# 3     Honda        TRX420FA5 FourTrax Rancher 4x4 Auto DCT IRS        NACH
# 4     Honda    TRX420FA6 FourTrax Rancher 4x4 Auto DCT IRS EPS        NACH
# ...     ...                                                ...         ...
# 1345  Honda  TRX520FA7 FourTrax Foreman Rubicon Auto DCT EP...        NACH
# 1346  Honda                           TRX650FA FourTrax Rincon        NACH
# 1347  Honda                  TRX650FGA FourTrax Rincon GPScape        NACH
# 1348  Honda                           TRX680FA FourTrax Rincon        NACH
# 1349  Honda                  TRX680FGA FourTrax Rincon GPScape        NACH
#
#                         Vendor Name   Vendor Notes Classification  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-04024-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Suzuki'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 51210-38F00'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08350'],
    
    'SKU': ['125412'],
    
}

list_models = [
    
'LT-F400F Eiger 4x4',
'LT-F400 Eiger 2x4',
'LT-A400F Eiger 4x4 Auto',
'LT-A400F KingQuad AS',
'LT-A400F KingQuad ASi',
'LT-A400F KingQuad ASi LE',
'LT-A400F KingQuad ASi SE',
'LT-A400F KingQuad ASi+',
'LT-A400F KingQuad ASi SE+',
'LT-A500F Vinson 500 4x4 Auto'


]

years = list(range(2002,2023))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                         Model Vendor Code  \
# 0    Suzuki            LT-F400F Eiger 4x4        NACH
# 1    Suzuki             LT-F400 Eiger 2x4        NACH
# 2    Suzuki       LT-A400F Eiger 4x4 Auto        NACH
# 3    Suzuki          LT-A400F KingQuad AS        NACH
# 4    Suzuki         LT-A400F KingQuad ASi        NACH
# ..      ...                           ...         ...
# 205  Suzuki      LT-A400F KingQuad ASi LE        NACH
# 206  Suzuki      LT-A400F KingQuad ASi SE        NACH
# 207  Suzuki        LT-A400F KingQuad ASi+        NACH
# 208  Suzuki     LT-A400F KingQuad ASi SE+        NACH
# 209  Suzuki  LT-A500F Vinson 500 4x4 Auto        NACH
#
#                        Vendor Name       Vendor Notes Classification  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 51210-38F00          Upper
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 51210-38F00          Upper
# 2    NACHMAN INTERNATIONAL CO. LTD  REF#: 51210-38F00          Upper
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08350-Upper.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Suzuki'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 51210-38F00'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08350'],
    
    'SKU': ['125412'],
    
}

list_models = [
    
'LT-F400F Eiger 4x4',
'LT-F400 Eiger 2x4',
'LT-A400F Eiger 4x4 Auto',
'LT-A400F KingQuad AS',
'LT-A400F KingQuad ASi',
'LT-A400F KingQuad ASi LE',
'LT-A400F KingQuad ASi SE',
'LT-A400F KingQuad ASi+',
'LT-A400F KingQuad ASi SE+',
'LT-A500F Vinson 500 4x4 Auto'


]

years = list(range(2002,2023))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                         Model Vendor Code  \
# 0    Suzuki            LT-F400F Eiger 4x4        NACH
# 1    Suzuki             LT-F400 Eiger 2x4        NACH
# 2    Suzuki       LT-A400F Eiger 4x4 Auto        NACH
# 3    Suzuki          LT-A400F KingQuad AS        NACH
# 4    Suzuki         LT-A400F KingQuad ASi        NACH
# ..      ...                           ...         ...
# 205  Suzuki      LT-A400F KingQuad ASi LE        NACH
# 206  Suzuki      LT-A400F KingQuad ASi SE        NACH
# 207  Suzuki        LT-A400F KingQuad ASi+        NACH
# 208  Suzuki     LT-A400F KingQuad ASi SE+        NACH
# 209  Suzuki  LT-A500F Vinson 500 4x4 Auto        NACH
#
#                        Vendor Name       Vendor Notes Classification  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 51210-38F00          Lower
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 51210-38F00          Lower
# 2    NACHMAN INTERNATIONAL CO. LTD  REF#: 51210-38F00          Lower
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08350-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Honda'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1015'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08553'],
    
    'SKU': ['125413'],
    
}

list_models = [
    
'TRX250TE FourTrax Recon ES',
'TRX250TM FourTrax Recon',


]

years = list(range(1997,2023))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#      Make                       Model Vendor Code  \
# 0   Honda  TRX250TE FourTrax Recon ES        NACH
# 1   Honda     TRX250TM FourTrax Recon        NACH
# 2   Honda  TRX250TE FourTrax Recon ES        NACH
# 3   Honda     TRX250TM FourTrax Recon        NACH
# 4   Honda  TRX250TE FourTrax Recon ES        NACH
# 5   Honda     TRX250TM FourTrax Recon        NACH
# 6   Honda  TRX250TE FourTrax Recon ES        NACH
# 7   Honda     TRX250TM FourTrax Recon        NACH
# 8   Honda  TRX250TE FourTrax Recon ES        NACH
# 9   Honda     TRX250TM FourTrax Recon        NACH
# 10  Honda  TRX250TE FourTrax Recon ES        NACH
# 11  Honda     TRX250TM FourTrax Recon        NACH
# 12  Honda  TRX250TE FourTrax Recon ES        NACH
# 13  Honda     TRX250TM FourTrax Recon        NACH
# 14  Honda  TRX250TE FourTrax Recon ES        NACH
# 15  Honda     TRX250TM FourTrax Recon        NACH
# 16  Honda  TRX250TE FourTrax Recon ES        NACH
# 17  Honda     TRX250TM FourTrax Recon        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08553-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Polaris'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1030'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08554'],
    
    'SKU': ['125414'],
    
}

list_models = [
    
'Big Boss 250 4x6',




]

years = list(range(1988,2024))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#           Make                                  Model Vendor Code  \
# 0      Polaris                       Big Boss 250 4x6        NACH
# 1      Polaris                       Big Boss 250 6x6        NACH
# 2      Polaris                       Trail Blazer 250        NACH
# 3      Polaris                         Trail Boss 250        NACH
# 4      Polaris                     Trail Boss 250 2x4        NACH
# ...        ...                                    ...         ...
# 10507  Polaris             Ranger XP Kinetic Ultimate        NACH
# 10508  Polaris       Ranger XP 1000 Waterfowl Edition        NACH
# 10509  Polaris  Ranger Crew XP 1000 Waterfowl Edition        NACH
# 10510  Polaris        Ranger XP 1000 Big Game Edition        NACH
# 10511  Polaris              Ranger XP Kinetic Premium        NACH
#
#                          Vendor Name   Vendor Notes Classification  \
# 0      NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1030          Lower
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08554-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Suzuki'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1022'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08556'],
    
    'SKU': ['125415'],
    
}

list_models = [
    
'LT230E QuadRunner',
'LT230GE',
'LT230S QuadSport',
'LT250EF',
'LT250R QuadRacer',
'LT250S',
'LT300E',
'LT-4WD QuadRunner 250',
'LT-4WDX King Quad 250',
'LT50 QuadRunner',
'LT500R QuadRacer',
'LT-F500F QuadRunner 4x4'




]

years = list(range(1985,2003))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                    Model Vendor Code  \
# 0    Suzuki        LT230E QuadRunner        NACH
# 1    Suzuki                  LT230GE        NACH
# 2    Suzuki         LT230S QuadSport        NACH
# 3    Suzuki                  LT250EF        NACH
# 4    Suzuki         LT250R QuadRacer        NACH
# ..      ...                      ...         ...
# 211  Suzuki    LT-4WD QuadRunner 250        NACH
# 212  Suzuki    LT-4WDX King Quad 250        NACH
# 213  Suzuki          LT50 QuadRunner        NACH
# 214  Suzuki         LT500R QuadRacer        NACH
# 215  Suzuki  LT-F500F QuadRunner 4x4        NACH
#
#                        Vendor Name   Vendor Notes Classification Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1022          Lower  Ball Joints
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1022          Lower  Ball Joints
# 2    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1022          Lower  Ball Joints
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08556-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Suzuki'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1022'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08556'],
    
    'SKU': ['125415'],
    
}

list_models = [
    
'LT-F250 Ozark',
'LT-F250 QuadRunner',
'LT-F250F QuadRunner 4x4',
'LT-F300F KingQuad 4x4',
'LT-4WD QuadRunner 250',
'LT-4WDX King Quad 250',
'LT-F4WDX King Quad 300',





]

years = list(range(1985,2003))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                    Model Vendor Code  \
# 0    Suzuki            LT-F250 Ozark        NACH
# 1    Suzuki       LT-F250 QuadRunner        NACH
# 2    Suzuki  LT-F250F QuadRunner 4x4        NACH
# 3    Suzuki    LT-F300F KingQuad 4x4        NACH
# 4    Suzuki    LT-4WD QuadRunner 250        NACH
# ..      ...                      ...         ...
# 121  Suzuki  LT-F250F QuadRunner 4x4        NACH
# 122  Suzuki    LT-F300F KingQuad 4x4        NACH
# 123  Suzuki    LT-4WD QuadRunner 250        NACH
# 124  Suzuki    LT-4WDX King Quad 250        NACH
# 125  Suzuki   LT-F4WDX King Quad 300        NACH
#
#                        Vendor Name   Vendor Notes Classification Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1022          Upper  Ball Joints
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1022          Upper  Ball Joints
# 2    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1022          Upper  Ball Joints
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08556-Upper.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Suzuki'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1017'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08576'],
    
    'SKU': ['125416'],
    
}

list_models = [
    
'LT-F250 Ozark',
'LT-F250 QuadRunner',
'LT-F250F QuadRunner 4x4',
'LT-F300F KingQuad 4x4',
'LT-4WD QuadRunner 250',
'LT-4WDX King Quad 250',
'LT-F4WDX King Quad 300',





]

years = list(range(1987,2005))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                    Model Vendor Code  \
# 0    Suzuki            LT-F250 Ozark        NACH
# 1    Suzuki       LT-F250 QuadRunner        NACH
# 2    Suzuki  LT-F250F QuadRunner 4x4        NACH
# 3    Suzuki    LT-F300F KingQuad 4x4        NACH
# 4    Suzuki    LT-4WD QuadRunner 250        NACH
# ..      ...                      ...         ...
# 121  Suzuki  LT-F250F QuadRunner 4x4        NACH
# 122  Suzuki    LT-F300F KingQuad 4x4        NACH
# 123  Suzuki    LT-4WD QuadRunner 250        NACH
# 124  Suzuki    LT-4WDX King Quad 250        NACH
# 125  Suzuki   LT-F4WDX King Quad 300        NACH
#
#                        Vendor Name   Vendor Notes Classification Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1017          Upper  Ball Joints
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1017          Upper  Ball Joints
# 2    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1017          Upper  Ball Joints
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08576-Upper.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Kawasaki'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1017'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08576'],
    
    'SKU': ['125416'],
    
}

list_models = [
    
'KSF250 Mojave',
'KXF250 Tecate 4',
'KEF300 Lakota Sport',
'KEF300 Lakota Utility',
'KLF300 Bayou 4x4',
'KLF400 Bayou 4x4'






]

years = list(range(1987,2005))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#          Make                  Model Vendor Code  \
# 0    Kawasaki          KSF250 Mojave        NACH
# 1    Kawasaki        KXF250 Tecate 4        NACH
# 2    Kawasaki    KEF300 Lakota Sport        NACH
# 3    Kawasaki  KEF300 Lakota Utility        NACH
# 4    Kawasaki       KLF300 Bayou 4x4        NACH
# ..        ...                    ...         ...
# 103  Kawasaki        KXF250 Tecate 4        NACH
# 104  Kawasaki    KEF300 Lakota Sport        NACH
# 105  Kawasaki  KEF300 Lakota Utility        NACH
# 106  Kawasaki       KLF300 Bayou 4x4        NACH
# 107  Kawasaki       KLF400 Bayou 4x4        NACH
#
#                        Vendor Name   Vendor Notes Classification Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1017          Upper  Ball Joints
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1017          Upper  Ball Joints
# 2    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1017          Upper  Ball Joints
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08576.a-Upper.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Kawasaki'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 7081867, 7081992,7082275, 7082422,7082487'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08577'],
    
    'SKU': ['125417'],
    
}

list_models = [
    
'General XP 1000 Deluxe',
'General XP 1000 Deluxe Ride Command Edition',
'General XP 4 1000 Deluxe',
'Ranger 1000',
'Ranger 1000 EPS',
'Ranger 1000 Premium',
'Ranger 1000 Premium + Winter Prep Package',
'Ranger XP 1000 EPS Northstar HVAC Edition',
'Ranger XP 1000 EPS High Lifter Edition',
'Ranger XP 1000 EPS Ranch Edition',
'Ranger XP 1000 EPS Hunter Edition',
'Ranger XP 1000 EPS',
'Ranger XP 1000',
'Ranger XP 1000 EPS Premium',
'Ranger XP 1000 EPS 20th Anniversary',
'Ranger XP 1000 Premium',
'Ranger XP 1000 NorthStar Edition',
'Ranger XP 1000 High Lifter Edition',
'Ranger XP 1000 Texas Edition',
'Ranger XP 1000 NorthStar Premium',
'Ranger XP 1000 NorthStar Edition Trail Boss',
'Ranger XP 1000 NorthStar Ultimate',
'Ranger XP 1000 Trail Boss',
'Ranger XP 1000 Waterfowl Edition',
'Ranger XP 1000 Big Game Edition',
'RZR XP 1000 EPS LE',
'RZR XP 4 1000 EPS',
'RZR XP 1000 EPS',
'RZR XP 1000 EPS High Lifter Edition',
'RZR XP 1000 EPS Desert Edition',
'RZR XP 1000 EPS Fox Edition',
'RZR XP Turbo EPS',
'RZR XP 4 Turbo EPS',
'RZR XP 4 1000 EPS High Lifter Edition',
'RZR XP 1000 EPS Velocity Blue LE',
'RZR XP 1000 EPS Gold Matte Metallic LE',
'RZR XP Turbo EPS Fox Edition',
'RZR XP Turbo EPS DYNAMIX Edition',
'RZR XP 4 Turbo EPS Fox Edition',
'RZR XP 1000 EPS Ride Command Edition',
'RZR XP 1000 EPS Trails and Rock Edition',
'RZR XP 4 1000 EPS Ride Command Edition',
'RZR XP 4 Turbo EPS DYNAMIX Edition',
'RZR XP Turbo S',
'RZR XP 1000 EPS DYNAMIX Edition',
'RZR XP Turbo EPS LE',
'RZR XP 4 1000 EPS Dynamix Edition',
'RZR XP 4 Turbo EPS LE',
'RZR XP 4 Turbo S',
'RZR XP 1000',
'RZR XP 1000 Premium',
'RZR XP 1000 Limited Edition',
'RZR XP 4 1000',
'RZR XP 4 1000 Premium',
'RZR XP 4 1000 Limited Edition',
'RZR XP Turbo',
'RZR XP 4 Turbo',
'RZR XP 4 Turbo S Velocity',
'RZR XP Turbo S Velocity',
'RZR XP 1000 Trails & Rocks',
'RZR XP 1000 High Lifter',
'RZR XP 4 1000 High Lifter',
'RZR XP 1000 Sport',
'RZR XP 4 1000 Sport',
'RZR PRO XP',
'RZR PRO XP Premium',
'RZR PRO XP Ultimate',
'RZR PRO XP 4',
'RZR PRO XP 4 Premium',
'RZR PRO XP 4 Ultimate',
'RZR PRO XP Orange Madness LE',
'RZR PRO XP 4 Orange Madness LE',
'RZR PRO XP Sport',
'RZR PRO XP 4 Sport',
'RZR Pro XP 4 Ultimate Rockford Fosgate LE',
'RZR Pro XP Ultimate Rockford Fosgate LE'




]

years = list(range(2014,2024))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#          Make                                        Model Vendor Code  \
# 0    Kawasaki                       General XP 1000 Deluxe        NACH
# 1    Kawasaki  General XP 1000 Deluxe Ride Command Edition        NACH
# 2    Kawasaki                     General XP 4 1000 Deluxe        NACH
# 3    Kawasaki                                  Ranger 1000        NACH
# 4    Kawasaki                              Ranger 1000 EPS        NACH
# ..        ...                                          ...         ...
# 755  Kawasaki               RZR PRO XP 4 Orange Madness LE        NACH
# 756  Kawasaki                             RZR PRO XP Sport        NACH
# 757  Kawasaki                           RZR PRO XP 4 Sport        NACH
# 758  Kawasaki    RZR Pro XP 4 Ultimate Rockford Fosgate LE        NACH
# 759  Kawasaki      RZR Pro XP Ultimate Rockford Fosgate LE        NACH
#
#                        Vendor Name  \
# 0    NACHMAN INTERNATIONAL CO. LTD
# 1    NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08577-Upper.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Kawasaki'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 7081867, 7081992,7082275, 7082422,7082487'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08577'],
    
    'SKU': ['125417'],
    
}

list_models = [
    
'General XP 1000 Deluxe',
'General XP 1000 Deluxe Ride Command Edition',
'General XP 4 1000 Deluxe',
'Ranger 1000',
'Ranger 1000 EPS',
'Ranger 1000 Premium',
'Ranger 1000 Premium + Winter Prep Package',
'Ranger XP 1000 EPS Northstar HVAC Edition',
'Ranger XP 1000 EPS High Lifter Edition',
'Ranger XP 1000 EPS Ranch Edition',
'Ranger XP 1000 EPS Hunter Edition',
'Ranger XP 1000 EPS',
'Ranger XP 1000',
'Ranger XP 1000 EPS Premium',
'Ranger XP 1000 EPS 20th Anniversary',
'Ranger XP 1000 Premium',
'Ranger XP 1000 NorthStar Edition',
'Ranger XP 1000 High Lifter Edition',
'Ranger XP 1000 Texas Edition',
'Ranger XP 1000 NorthStar Premium',
'Ranger XP 1000 NorthStar Edition Trail Boss',
'Ranger XP 1000 NorthStar Ultimate',
'Ranger XP 1000 Trail Boss',
'Ranger XP 1000 Waterfowl Edition',
'Ranger XP 1000 Big Game Edition',
'RZR XP 1000 EPS LE',
'RZR XP 4 1000 EPS',
'RZR XP 1000 EPS',
'RZR XP 1000 EPS High Lifter Edition',
'RZR XP 1000 EPS Desert Edition',
'RZR XP 1000 EPS Fox Edition',
'RZR XP Turbo EPS',
'RZR XP 4 Turbo EPS',
'RZR XP 4 1000 EPS High Lifter Edition',
'RZR XP 1000 EPS Velocity Blue LE',
'RZR XP 1000 EPS Gold Matte Metallic LE',
'RZR XP Turbo EPS Fox Edition',
'RZR XP Turbo EPS DYNAMIX Edition',
'RZR XP 4 Turbo EPS Fox Edition',
'RZR XP 1000 EPS Ride Command Edition',
'RZR XP 1000 EPS Trails and Rock Edition',
'RZR XP 4 1000 EPS Ride Command Edition',
'RZR XP 4 Turbo EPS DYNAMIX Edition',
'RZR XP Turbo S',
'RZR XP 1000 EPS DYNAMIX Edition',
'RZR XP Turbo EPS LE',
'RZR XP 4 1000 EPS Dynamix Edition',
'RZR XP 4 Turbo EPS LE',
'RZR XP 4 Turbo S',
'RZR XP 1000',
'RZR XP 1000 Premium',
'RZR XP 1000 Limited Edition',
'RZR XP 4 1000',
'RZR XP 4 1000 Premium',
'RZR XP 4 1000 Limited Edition',
'RZR XP Turbo',
'RZR XP 4 Turbo',
'RZR XP 4 Turbo S Velocity',
'RZR XP Turbo S Velocity',
'RZR XP 1000 Trails & Rocks',
'RZR XP 1000 High Lifter',
'RZR XP 4 1000 High Lifter',
'RZR XP 1000 Sport',
'RZR XP 4 1000 Sport',
'RZR PRO XP',
'RZR PRO XP Premium',
'RZR PRO XP Ultimate',
'RZR PRO XP 4',
'RZR PRO XP 4 Premium',
'RZR PRO XP 4 Ultimate',
'RZR PRO XP Orange Madness LE',
'RZR PRO XP 4 Orange Madness LE',
'RZR PRO XP Sport',
'RZR PRO XP 4 Sport',
'RZR Pro XP 4 Ultimate Rockford Fosgate LE',
'RZR Pro XP Ultimate Rockford Fosgate LE'




]

years = list(range(2014,2024))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#          Make                                        Model Vendor Code  \
# 0    Kawasaki                       General XP 1000 Deluxe        NACH
# 1    Kawasaki  General XP 1000 Deluxe Ride Command Edition        NACH
# 2    Kawasaki                     General XP 4 1000 Deluxe        NACH
# 3    Kawasaki                                  Ranger 1000        NACH
# 4    Kawasaki                              Ranger 1000 EPS        NACH
# ..        ...                                          ...         ...
# 755  Kawasaki               RZR PRO XP 4 Orange Madness LE        NACH
# 756  Kawasaki                             RZR PRO XP Sport        NACH
# 757  Kawasaki                           RZR PRO XP 4 Sport        NACH
# 758  Kawasaki    RZR Pro XP 4 Ultimate Rockford Fosgate LE        NACH
# 759  Kawasaki      RZR Pro XP Ultimate Rockford Fosgate LE        NACH
#
#                        Vendor Name  \
# 0    NACHMAN INTERNATIONAL CO. LTD
# 1    NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08577-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Yamaha'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 1SC-F3549-00/10'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08579'],
    
    'SKU': ['127495'],
    
}

list_models = [
    
'YFM300 Grizzly Automatic'


]

years = list(range(2012,2014))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#      Make                     Model Vendor Code  \
# 0  Yamaha  YFM300 Grizzly Automatic        NACH
# 1  Yamaha  YFM300 Grizzly Automatic        NACH
#
#                      Vendor Name           Vendor Notes Classification  \
# 0  NACHMAN INTERNATIONAL CO. LTD  REF#: 1SC-F3549-00/10          Lower
# 1  NACHMAN INTERNATIONAL CO. LTD  REF#: 1SC-F3549-00/10          Lower
#
#   Product Type       MPN     SKU  Year
# 0  Ball Joints  AT-08579  127495  2012
# 1  Ball Joints  AT-08579  127495  2013

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08579-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Yamaha'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 1SC-F3549-00/10'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08579'],
    
    'SKU': ['127495'],
    
}

list_models = [
    
'YFM300 Grizzly Automatic'


]

years = list(range(2012,2014))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#      Make                     Model Vendor Code  \
# 0  Yamaha  YFM300 Grizzly Automatic        NACH
# 1  Yamaha  YFM300 Grizzly Automatic        NACH
#
#                      Vendor Name           Vendor Notes Classification  \
# 0  NACHMAN INTERNATIONAL CO. LTD  REF#: 1SC-F3549-00/10          Upper
# 1  NACHMAN INTERNATIONAL CO. LTD  REF#: 1SC-F3549-00/10          Upper
#
#   Product Type       MPN     SKU  Year
# 0  Ball Joints  AT-08579  127495  2012
# 1  Ball Joints  AT-08579  127495  2013

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08579-Upper.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Arctic Cat'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 0405-001, 0405-049, 0405-068, 0405-115, 0405-483'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08580'],
    
    'SKU': ['125418'],
    
}

list_models = [
    
'250 2x4',
'250 4x4',
'300 2x4',
'300 4x4',
'366 4x4 Auto',
'375 Auto 2x4',
'375 Auto 4x4',
'400 2x4',
'400 2x4 Auto',
'400 4x4',
'400 4x4 ACT',
'400 4x4 Auto',
'400 4x4 Auto ACT',
'400 4x4 Auto LE',
'400 4x4 Auto MRP',
'400 4x4 Auto TBX',
'400 4x4 Auto TRV',
'400 4x4 Auto TRV Plus',
'400 4x4 Auto VP',
'400 4x4 VP',
'400 2x4 FIS',
'400 4x4 FIS',
'50 2x4',
'500 4x4',
'500 4x4 Auto',
'500 4x4 Auto LE',
'500 4x4 Auto M4',
'500 4x4 Auto TBX',
'500 4x4 Auto TRV',
'500 4x4 FIS',
'500 4x4 Auto FIS',
'Prowler 550',
'550 4x4 Auto',
'550 4x4 Auto LE',
'550 4x4 Auto TRV',
'550 4x4 Auto TRV LE',
'Prowler XT 550',
'550 TRV Cruiser',
'550 TRV S GT',
'550 TRV GT',
'550 LTD',
'550 S',
'TRV 550i Crusier',
'TRV 550i GT',
'550i LTD',
'550 H1 EFI',
'550i GT',
'550',
'Prowler XT 550i',
'550 XT',
'550 Core',
'TRV 550 LTD',
'TRV 550 XT',
'XR 550',
'XR 550 XT',
'XR 550 LTD',
'Alterra 550',
'Alterra 550 XT',
'Alterra TRV 550 XT',
'Alterra 570',
'Alterra 570 EPS',
'Alterra 570 EPS SE',
'650 4x4 Auto',
'650 4x4 Auto LE',
'650 H1 4x4 Auto',
'650 H1 4x4 Auto LE',
'650 H1 4x4 Auto SE',
'650 H1 4x4 Auto TBX',
'650 H1 4x4 Auto TRV',
'650 H1 4x4 Auto TRV Plus',
'650 H1 4x4 Auto TRV Plus LE',
'650 V-2 4x4 Auto',
'650 V-2 4x4 Auto LE/TS',
'Prowler 650 4x4 Auto',
'Prowler 650 H1',
'Prowler XT 650 4x4 Auto',
'Prowler XT 650 4x4 Auto M4',
'Prowler XT 650 H1',
'650 4x4 Auto TBX',
'650 V-2 4x4 Auto MRP',
'650 H1 4x4 Auto Mud Pro',
'700 Diesel',
'700 EFI 4x4 Auto',
'700 EFI 4x4 Auto LE',
'700 EFI 4x4 Auto SE',
'700 EFI 4x4 Auto TRV LE',
'700 EFI H1 4x4 Auto SE',
'Prowler XT 700',
'Prowler XTX 700 LE',
'Prowler XTX 700 H1 EFI',
'700 EFI H1 4x4 Auto Mud Pro',
'700 EFI H1 4x4 Auto TRV',
'700 EFI H1 4x4 Auto LE',
'700 EFI H1 4x4 Auto',
'700 EFI 4x4 Auto TRV Cruiser',
'700 EFI 4x4 Auto M4',
'700 EFI H1 4x4 Auto TBX',
'700 Super Duty Diesel',
'Prowler XTX 700',
'Prowler HDX 700',
'700 TRV GT',
'700 LTD',
'700 S',
'700',
'MudPro 700',
'TBX 700 LTD',
'TRV 700i GT',
'TRV 700i Cruiser',
'700i LTD',
'700i GT',
'700i',
'MudPro 700 LTD',
'MudPro 700i',
'TBX 700i GT',
'Prowler HDX 700i',
'Prowler XTX 700i',
'700 XT',
'700 Core',
'TRV 700 LTD',
'TRV 700 XT',
'TBX 700 XT',
'TBX 700',
'Prowler HDX 700 Limited',
'Prowler HDX 700 XT',
'XR 700 XT',
'XR 700 LTD',
'XR 700',
'Alterra 700',
'Alterra 700 XT',
'TRV 700 SE',
'HDX 700 SE Hunter Edition',
'HDX 700 XT',
'Alterra TRV 700 XT',
'TBX 700 SE',
'HDX 700 CREW XT',
'Prowler 700 XT',
'VLX 700',
'Alterra TRV 700',
'Alterra TBX 700',
'Alterra 700 EPS SE',
'Alterra TRV 700 EPS',
'Thundercat 1000 4x4 Auto',
'Prowler XTZ 1000 H2 EFI',
'Prowler XTZ 1000 Baja',
'1000 TRV Cruiser',
'SBS 1000',
'Thundercat 1000 4x4 Auto LE',
'1000 EFI H2 4x4 Auto Mud Pro',
'1000 EFI H2 4x4 Auto TRV',
'Prowler XTZ 1000',
'1000 LTD',
'MudPro 1000',
'TRV 1000i Cruiser',
'TRV 1000i GT',
'1000i GT',
'MudPro 1000 LTD',
'Wildcat 1000',
'Prowler XTZ 1000i',
'Wildcat 1000 LTD',
'1000 XT',
'TRV 1000 LTD',
'Wildcat 4 1000',
'Wildcat X 1000',
'TRV 1000 XT',
'Prowler XT 1000',
'Alterra TRV 1000 XT',
'MudPro 1000 SE',
'Prowler 1000 XT',
'MudPro 650',
'Prowler HDX 500 Limited',
'Prowler HDX 500 XT',
'Prowler HDX 500',
'Prowler 500',
'Prowler Pro',
'Prowler Pro Crew',
'Prowler Pro Ranch Edition',
'Prowler Pro Crew Ranch Edition',
'Prowler Pro Crew LTD',
'Prowler Pro EPS',
'Prowler Pro XT',
'Prowler Pro Crew EPS',
'Prowler Pro LTD',
'Prowler Pro Crew XT',

]

years = list(range(1996,2025))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#             Make                 Model Vendor Code  \
# 0     Arctic Cat               250 2x4        NACH
# 1     Arctic Cat               250 4x4        NACH
# 2     Arctic Cat               300 2x4        NACH
# 3     Arctic Cat               300 4x4        NACH
# 4     Arctic Cat          366 4x4 Auto        NACH
# ...          ...                   ...         ...
# 5302  Arctic Cat       Prowler Pro EPS        NACH
# 5303  Arctic Cat        Prowler Pro XT        NACH
# 5304  Arctic Cat  Prowler Pro Crew EPS        NACH
# 5305  Arctic Cat       Prowler Pro LTD        NACH
# 5306  Arctic Cat   Prowler Pro Crew XT        NACH
#
#                         Vendor Name  \
# 0     NACHMAN INTERNATIONAL CO. LTD
# 1     NACHMAN INTERNATIONAL CO. LTD
# 2     NACHMAN INTERNATIONAL CO. LTD
# 3     NACHMAN INTERNATIONAL CO. LTD
# 4     NACHMAN INTERNATIONAL CO. LTD
# ...                             ...
# 5302  NACHMAN INTERNATIONAL CO. LTD
# 5303  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08580-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Kymco'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 53410-PRB1-900'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08580'],
    
    'SKU': ['125418'],
    
}

list_models = [
    
'MXU375 IRS',
'MXU375 IRS LE',
'MXU375 4x4 IRS',
'UXV 500 4X4',
'UXV 500 4X4 LE',
'UXV 500 4X4 SE',
'UXV 500i SE',
'UXV 500i 4X4',
'UXV 500i LE',
'UXV 500i SP',
'UXV 500i HE',
'UXV 500i TURF',
'UXV 500',
'UXV 500i',
'UXV 500i Camo',
'UXV 500i LE 50th Anniversary',
'UXV 500i G',
'UXV 500i G Turf',
'UXV 700i',
'UXV 700i HE',
'UXV 700i TURF',
'UXV 700i LE',
'UXV 700i SP',
'UXV 700i Camo',
'UXV 700i LE 50th Anniversary',
'UXV 700i LE EPS',
'UXV 700i LE EPS Camo',
'UXV 700i LE Prime',
'UXV 700i LE Hunter'


]

years = list(range(1996,2025))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#       Make                         Model Vendor Code  \
# 0    Kymco                    MXU375 IRS        NACH
# 1    Kymco                 MXU375 IRS LE        NACH
# 2    Kymco                MXU375 4x4 IRS        NACH
# 3    Kymco                   UXV 500 4X4        NACH
# 4    Kymco                UXV 500 4X4 LE        NACH
# ..     ...                           ...         ...
# 836  Kymco  UXV 700i LE 50th Anniversary        NACH
# 837  Kymco               UXV 700i LE EPS        NACH
# 838  Kymco          UXV 700i LE EPS Camo        NACH
# 839  Kymco             UXV 700i LE Prime        NACH
# 840  Kymco            UXV 700i LE Hunter        NACH
#
#                        Vendor Name          Vendor Notes Classification  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 53410-PRB1-900          Lower
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 53410-PRB1-900          Lower
# 2    NACHMAN INTERNATIONAL CO. LTD  REF#: 53410-PRB1-900          Lower
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08580.a-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Arctic Cat'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 0405-001, 0405-049, 0405-068, 0405-115, 0405-483'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08580'],
    
    'SKU': ['125418'],
    
}

list_models = [
    
'250 2x4',
'250 4x4',
'300 2x4',
'300 4x4',
'366 4x4 Auto',
'375 Auto 2x4',
'375 Auto 4x4',
'400 2x4',
'400 2x4 Auto',
'400 4x4',
'400 4x4 ACT',
'400 4x4 Auto',
'400 4x4 Auto ACT',
'400 4x4 Auto LE',
'400 4x4 Auto MRP',
'400 4x4 Auto TBX',
'400 4x4 Auto TRV',
'400 4x4 Auto TRV Plus',
'400 4x4 Auto VP',
'400 4x4 VP',
'400 2x4 FIS',
'400 4x4 FIS',
'50 2x4',
'500 4x4',
'500 4x4 Auto',
'500 4x4 Auto LE',
'500 4x4 Auto M4',
'500 4x4 Auto TBX',
'500 4x4 Auto TRV',
'500 4x4 FIS',
'500 4x4 Auto FIS',
'Prowler 550',
'550 4x4 Auto',
'550 4x4 Auto LE',
'550 4x4 Auto TRV',
'550 4x4 Auto TRV LE',
'Prowler XT 550',
'550 TRV Cruiser',
'550 TRV S GT',
'550 TRV GT',
'550 LTD',
'550 S',
'TRV 550i Crusier',
'TRV 550i GT',
'550i LTD',
'550 H1 EFI',
'550i GT',
'550',
'Prowler XT 550i',
'550 XT',
'550 Core',
'TRV 550 LTD',
'TRV 550 XT',
'XR 550',
'XR 550 XT',
'XR 550 LTD',
'Alterra 550',
'Alterra 550 XT',
'Alterra TRV 550 XT',
'Alterra 570',
'Alterra 570 EPS',
'Alterra 570 EPS SE',
'650 4x4 Auto',
'650 4x4 Auto LE',
'650 H1 4x4 Auto',
'650 H1 4x4 Auto LE',
'650 H1 4x4 Auto SE',
'650 H1 4x4 Auto TBX',
'650 H1 4x4 Auto TRV',
'650 H1 4x4 Auto TRV Plus',
'650 H1 4x4 Auto TRV Plus LE',
'650 V-2 4x4 Auto',
'650 V-2 4x4 Auto LE/TS',
'Prowler 650 4x4 Auto',
'Prowler 650 H1',
'Prowler XT 650 4x4 Auto',
'Prowler XT 650 4x4 Auto M4',
'Prowler XT 650 H1',
'650 4x4 Auto TBX',
'650 V-2 4x4 Auto MRP',
'650 H1 4x4 Auto Mud Pro',
'700 Diesel',
'700 EFI 4x4 Auto',
'700 EFI 4x4 Auto LE',
'700 EFI 4x4 Auto SE',
'700 EFI 4x4 Auto TRV LE',
'700 EFI H1 4x4 Auto SE',
'Prowler XT 700',
'Prowler XTX 700 LE',
'Prowler XTX 700 H1 EFI',
'700 EFI H1 4x4 Auto Mud Pro',
'700 EFI H1 4x4 Auto TRV',
'700 EFI H1 4x4 Auto LE',
'700 EFI H1 4x4 Auto',
'700 EFI 4x4 Auto TRV Cruiser',
'700 EFI 4x4 Auto M4',
'700 EFI H1 4x4 Auto TBX',
'700 Super Duty Diesel',
'Prowler XTX 700',
'Prowler HDX 700',
'700 TRV GT',
'700 LTD',
'700 S',
'700',
'MudPro 700',
'TBX 700 LTD',
'TRV 700i GT',
'TRV 700i Cruiser',
'700i LTD',
'700i GT',
'700i',
'MudPro 700 LTD',
'MudPro 700i',
'TBX 700i GT',
'Prowler HDX 700i',
'Prowler XTX 700i',
'700 XT',
'700 Core',
'TRV 700 LTD',
'TRV 700 XT',
'TBX 700 XT',
'TBX 700',
'Prowler HDX 700 Limited',
'Prowler HDX 700 XT',
'XR 700 XT',
'XR 700 LTD',
'XR 700',
'Alterra 700',
'Alterra 700 XT',
'TRV 700 SE',
'HDX 700 SE Hunter Edition',
'HDX 700 XT',
'Alterra TRV 700 XT',
'TBX 700 SE',
'HDX 700 CREW XT',
'Prowler 700 XT',
'VLX 700',
'Alterra TRV 700',
'Alterra TBX 700',
'Alterra 700 EPS SE',
'Alterra TRV 700 EPS',
'Thundercat 1000 4x4 Auto',
'Prowler XTZ 1000 H2 EFI',
'Prowler XTZ 1000 Baja',
'1000 TRV Cruiser',
'SBS 1000',
'Thundercat 1000 4x4 Auto LE',
'1000 EFI H2 4x4 Auto Mud Pro',
'1000 EFI H2 4x4 Auto TRV',
'Prowler XTZ 1000',
'1000 LTD',
'MudPro 1000',
'TRV 1000i Cruiser',
'TRV 1000i GT',
'1000i GT',
'MudPro 1000 LTD',
'Wildcat 1000',
'Prowler XTZ 1000i',
'Wildcat 1000 LTD',
'1000 XT',
'TRV 1000 LTD',
'Wildcat 4 1000',
'Wildcat X 1000',
'TRV 1000 XT',
'Prowler XT 1000',
'Alterra TRV 1000 XT',
'MudPro 1000 SE',
'Prowler 1000 XT',
'MudPro 650',
'Prowler HDX 500 Limited',
'Prowler HDX 500 XT',
'Prowler HDX 500',
'Prowler 500',
'Prowler Pro',
'Prowler Pro Crew',
'Prowler Pro Ranch Edition',
'Prowler Pro Crew Ranch Edition',
'Prowler Pro Crew LTD',
'Prowler Pro EPS',
'Prowler Pro XT',
'Prowler Pro Crew EPS',
'Prowler Pro LTD',
'Prowler Pro Crew XT',

]

years = list(range(1996,2025))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#             Make                 Model Vendor Code  \
# 0     Arctic Cat               250 2x4        NACH
# 1     Arctic Cat               250 4x4        NACH
# 2     Arctic Cat               300 2x4        NACH
# 3     Arctic Cat               300 4x4        NACH
# 4     Arctic Cat          366 4x4 Auto        NACH
# ...          ...                   ...         ...
# 5302  Arctic Cat       Prowler Pro EPS        NACH
# 5303  Arctic Cat        Prowler Pro XT        NACH
# 5304  Arctic Cat  Prowler Pro Crew EPS        NACH
# 5305  Arctic Cat       Prowler Pro LTD        NACH
# 5306  Arctic Cat   Prowler Pro Crew XT        NACH
#
#                         Vendor Name  \
# 0     NACHMAN INTERNATIONAL CO. LTD
# 1     NACHMAN INTERNATIONAL CO. LTD
# 2     NACHMAN INTERNATIONAL CO. LTD
# 3     NACHMAN INTERNATIONAL CO. LTD
# 4     NACHMAN INTERNATIONAL CO. LTD
# ...                             ...
# 5302  NACHMAN INTERNATIONAL CO. LTD
# 5303  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08580-Upper.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['Kymco'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 53410-PRB1-900'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08580'],
    
    'SKU': ['125418'],
    
}

list_models = [
    
'MXU375 IRS',
'MXU375 IRS LE',
'MXU375 4x4 IRS',
'UXV 500 4X4',
'UXV 500 4X4 LE',
'UXV 500 4X4 SE',
'UXV 500i SE',
'UXV 500i 4X4',
'UXV 500i LE',
'UXV 500i SP',
'UXV 500i HE',
'UXV 500i TURF',
'UXV 500',
'UXV 500i',
'UXV 500i Camo',
'UXV 500i LE 50th Anniversary',
'UXV 500i G',
'UXV 500i G Turf',
'UXV 700i',
'UXV 700i HE',
'UXV 700i TURF',
'UXV 700i LE',
'UXV 700i SP',
'UXV 700i Camo',
'UXV 700i LE 50th Anniversary',
'UXV 700i LE EPS',
'UXV 700i LE EPS Camo',
'UXV 700i LE Prime',
'UXV 700i LE Hunter'


]

years = list(range(1996,2025))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#       Make                         Model Vendor Code  \
# 0    Kymco                    MXU375 IRS        NACH
# 1    Kymco                 MXU375 IRS LE        NACH
# 2    Kymco                MXU375 4x4 IRS        NACH
# 3    Kymco                   UXV 500 4X4        NACH
# 4    Kymco                UXV 500 4X4 LE        NACH
# ..     ...                           ...         ...
# 836  Kymco  UXV 700i LE 50th Anniversary        NACH
# 837  Kymco               UXV 700i LE EPS        NACH
# 838  Kymco          UXV 700i LE EPS Camo        NACH
# 839  Kymco             UXV 700i LE Prime        NACH
# 840  Kymco            UXV 700i LE Hunter        NACH
#
#                        Vendor Name          Vendor Notes Classification  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 53410-PRB1-900          Lower
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 53410-PRB1-900          Lower
# 2    NACHMAN INTERNATIONAL CO. LTD  REF#: 53410-PRB1-900          Lower
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08580.a-Upper.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['at/utv'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1019'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08581'],
    
    'SKU': ['125419'],
    
}

list_models = [
    
'KFX400',
'LT-F250 Ozark',
'LT-Z400 QuadSport Z',
'LT-Z400 QuadSport Z LE',
'LT-A450X KingQuad AXi 4x4',
'LT-A50 QuadMaster',
'LT-A500F Vinson 500 4x4 Auto',
'LT-A500 KingQuad AXi',
'LT-A500 KingQuad AXi Power Steering',
'LT-A500 KingQuad AXi Power Steering SE',
'LT-A500 KingQuad AXi Power Steering SE Rugged',
'LT-A500 KingQuad AXi Power Steering SE+',
'LT-A500 KingQuad AXi Power Steering Rugged',
'LT-A500 KingQuad AXi Power Steering SE+ Rugged',
'LT-A700X KingQuad 4x4',
'LT-A750X KingQuad AXi 4x4',
'LT-A750 KingQuad AXi Power Steering',
'LT-A750X KingQuad AXi 4x4 LE',
'LT-A750 KingQuad AXi Power Steering LE',
'LT-A750 KingQuad AXi Power Steering SE',
'LT-A750 KingQuad AXi Power Steering SE Rugged',
'LT-A750 KingQuad AXi Power Steering SE+',
'LT-A750 KingQuad AXi Power Steering Rugged',
'LT-A750 KingQuad AXi Power Steering SE+ Rugged'




]

years = list(range(2004,2023))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                                           Model Vendor Code  \
# 0    at/utv                                          KFX400        NACH
# 1    at/utv                                   LT-F250 Ozark        NACH
# 2    at/utv                             LT-Z400 QuadSport Z        NACH
# 3    at/utv                          LT-Z400 QuadSport Z LE        NACH
# 4    at/utv                       LT-A450X KingQuad AXi 4x4        NACH
# ..      ...                                             ...         ...
# 451  at/utv          LT-A750 KingQuad AXi Power Steering SE        NACH
# 452  at/utv   LT-A750 KingQuad AXi Power Steering SE Rugged        NACH
# 453  at/utv         LT-A750 KingQuad AXi Power Steering SE+        NACH
# 454  at/utv      LT-A750 KingQuad AXi Power Steering Rugged        NACH
# 455  at/utv  LT-A750 KingQuad AXi Power Steering SE+ Rugged        NACH
#
#                        Vendor Name   Vendor Notes Classification Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08581-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['at/utv'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1019'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08581'],
    
    'SKU': ['125419'],
    
}

list_models = [
    
'KFX400',
'LT-F250 Ozark',
'LT-Z400 QuadSport Z',
'LT-Z400 QuadSport Z LE',
'LT-A450X KingQuad AXi 4x4',
'LT-A50 QuadMaster',
'LT-A500F Vinson 500 4x4 Auto',
'LT-A500 KingQuad AXi',
'LT-A500 KingQuad AXi Power Steering',
'LT-A500 KingQuad AXi Power Steering SE',
'LT-A500 KingQuad AXi Power Steering SE Rugged',
'LT-A500 KingQuad AXi Power Steering SE+',
'LT-A500 KingQuad AXi Power Steering Rugged',
'LT-A500 KingQuad AXi Power Steering SE+ Rugged',
'LT-A700X KingQuad 4x4',
'LT-A750X KingQuad AXi 4x4',
'LT-A750 KingQuad AXi Power Steering',
'LT-A750X KingQuad AXi 4x4 LE',
'LT-A750 KingQuad AXi Power Steering LE',
'LT-A750 KingQuad AXi Power Steering SE',
'LT-A750 KingQuad AXi Power Steering SE Rugged',
'LT-A750 KingQuad AXi Power Steering SE+',
'LT-A750 KingQuad AXi Power Steering Rugged',
'LT-A750 KingQuad AXi Power Steering SE+ Rugged'




]

years = list(range(2004,2023))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                                           Model Vendor Code  \
# 0    at/utv                                          KFX400        NACH
# 1    at/utv                                   LT-F250 Ozark        NACH
# 2    at/utv                             LT-Z400 QuadSport Z        NACH
# 3    at/utv                          LT-Z400 QuadSport Z LE        NACH
# 4    at/utv                       LT-A450X KingQuad AXi 4x4        NACH
# ..      ...                                             ...         ...
# 451  at/utv          LT-A750 KingQuad AXi Power Steering SE        NACH
# 452  at/utv   LT-A750 KingQuad AXi Power Steering SE Rugged        NACH
# 453  at/utv         LT-A750 KingQuad AXi Power Steering SE+        NACH
# 454  at/utv      LT-A750 KingQuad AXi Power Steering Rugged        NACH
# 455  at/utv  LT-A750 KingQuad AXi Power Steering SE+ Rugged        NACH
#
#                        Vendor Name   Vendor Notes Classification Product Type  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08581-Upper.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['at/utv'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1033'],
    
    'Classification': ['Lower'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08582'],
    
    'SKU': ['125420'],
    
}

list_models = [
    
'KVF360 Prairie 2x4',
'KVF360 Prairie 4x4',
'KVF650 Brute Force 4x4',
'KVF650 Brute Force 4x4i',
'KVF650 Prairie 4x4',
'KVF700 Prairie 4x4',
'KFX700',
'KVF750 Brute Force 4x4i',
'KVF750 Brute Force 4x4i EPS',
'KVF750 Brute Force 4x4i EPS Camo',
'KAF820 Mule PRO-FXT',
'KAF820 Mule PRO-FXT EPS',
'KAF820 Mule PRO-FXT EPS LE',
'KAF820 Mule PRO-FXT EPS Camo',
'KAF820 Mule PRO-FXT Ranch Edition',
'KAF820 Mule PRO-FX',
'KAF820 Mule PRO-FX EPS',
'KAF820 Mule PRO-FX EPS Camo',
'KAF820 Mule PRO-FX EPS LE',
'KAF820 Mule PRO-FXR',
'KAF820 Mule PRO-FX Ranch Edition',
'KAF820 Mule PRO-FXT Ranch Edition Platinum',
'KRF800 Teryx',
'KRF800 Teryx LE',
'KRF800 Teryx Camo',
'KRF800 Teryx S LE',
'KAF620 Mule 2500',
'KAF620 Mule 2510 4x4',
'KAF950 Mule 2510 Diesel',
'KAF620 Mule 2520',
'KAF620 Mule 3000',
'KAF620 Mule 3010 4x4',
'KAF620 Mule 3010 Trans 4x4',
'KAF620 Mule 3020',
'KAF950 Mule 3010 Diesel 4x4',
'KAF950 Mule 3010 Trans 4x4 Diesel',
'LT-V700F Twin Peaks 700 4x4',





]

years = list(range(2004,2023))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                              Model Vendor Code  \
# 0    at/utv                 KVF360 Prairie 2x4        NACH
# 1    at/utv                 KVF360 Prairie 4x4        NACH
# 2    at/utv             KVF650 Brute Force 4x4        NACH
# 3    at/utv            KVF650 Brute Force 4x4i        NACH
# 4    at/utv                 KVF650 Prairie 4x4        NACH
# ..      ...                                ...         ...
# 698  at/utv         KAF620 Mule 3010 Trans 4x4        NACH
# 699  at/utv                   KAF620 Mule 3020        NACH
# 700  at/utv        KAF950 Mule 3010 Diesel 4x4        NACH
# 701  at/utv  KAF950 Mule 3010 Trans 4x4 Diesel        NACH
# 702  at/utv        LT-V700F Twin Peaks 700 4x4        NACH
#
#                        Vendor Name   Vendor Notes Classification Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1033          Lower  Ball Joints
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1033          Lower  Ball Joints
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08582-Lower.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

data1 = {
    'Make': ['at/utv'],
    'Model': ['All Models'],
    'Vendor Code': ['NACH'],
    'Vendor Name': ['NACHMAN INTERNATIONAL CO. LTD'],
    'Vendor Notes': ['REF#: 42-1033'],
    
    'Classification': ['Upper'],
    
    'Product Type': ['Ball Joints'],
        
    'MPN': ['AT-08582'],
    
    'SKU': ['125420'],
    
}

list_models = [
    
'KFX450R',
'KVF650 Brute Force 4x4',
'KVF650 Brute Force 4x4i',
'KVF650 Prairie 4x4',
'KFX700',
'KVF700 Prairie 4x4',
'KVF750 Brute Force 4x4i',
'KVF750 Brute Force 4x4i EPS',
'KVF750 Brute Force 4x4i EPS Camo',
'KRF750 Teryx 4x4',
'KRF750 Teryx FI 4x4 LE',
'KRF750 Teryx NRA Outdoors',
'KRF750 Teryx FI 4x4 LE Sport',
'KRF750 Teryx FI 4x4 Sport',
'KRF750 Teryx FI 4x4',
'KRF750 Teryx FI 4x4 LE SGE',
'KRF750 Teryx FI 4x4 LE Camo',
'KAF820 Mule PRO-FXT',
'KAF820 Mule PRO-FXT EPS',
'KAF820 Mule PRO-FXT EPS LE',
'KAF820 Mule PRO-FXT EPS Camo',
'KAF820 Mule PRO-FXT Ranch Edition',
'KAF820 Mule PRO-FX',
'KAF820 Mule PRO-FX EPS',
'KAF820 Mule PRO-FX EPS Camo',
'KAF820 Mule PRO-FX EPS LE',
'KAF820 Mule PRO-FXR',
'KAF820 Mule PRO-FX Ranch Edition',
'KAF820 Mule PRO-FXT Ranch Edition Platinum',
'KRF800 Teryx',
'KRF800 Teryx LE',
'KRF800 Teryx Camo',
'KRF800 Teryx S LE',
'LT-V700F Twin Peaks 700 4x4',






]

years = list(range(2004,2023))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([ generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
        

final_df = pd.concat(dfs, ignore_index = True)

final_df
# Out:
#        Make                        Model Vendor Code  \
# 0    at/utv                      KFX450R        NACH
# 1    at/utv       KVF650 Brute Force 4x4        NACH
# 2    at/utv      KVF650 Brute Force 4x4i        NACH
# 3    at/utv           KVF650 Prairie 4x4        NACH
# 4    at/utv                       KFX700        NACH
# ..      ...                          ...         ...
# 641  at/utv                 KRF800 Teryx        NACH
# 642  at/utv              KRF800 Teryx LE        NACH
# 643  at/utv            KRF800 Teryx Camo        NACH
# 644  at/utv            KRF800 Teryx S LE        NACH
# 645  at/utv  LT-V700F Twin Peaks 700 4x4        NACH
#
#                        Vendor Name   Vendor Notes Classification Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1033          Upper  Ball Joints
# 1    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1033          Upper  Ball Joints
# 2    NACHMAN INTERNATIONAL CO. LTD  REF#: 42-1033          Upper  Ball Joints
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\01_SECTION 08 - BALL JOINTS ( 01-16-24 )\file_merge\AT-08582-Upper.csv"
final_df.to_csv(file_path, index = False)
